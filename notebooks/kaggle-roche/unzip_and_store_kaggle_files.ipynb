# %%
ACCESS_KEY = "AKIASQM2EIHRHDSLMHPW"
SECRET_KEY = "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"

import boto3
session = boto3.Session(
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY,
)
s3 = session.client('s3')
bucket_list = s3.list_buckets()['Buckets']
# Output the bucket names
print('Existing buckets:')
for bucket in bucket_list:
    print(f'  {bucket["Name"]}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/botocore/vendored/requests/packages/urllib3/_collections.py:1: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated, and in 3.8 it will stop working
#   from collections import Mapping, MutableMapping
# Existing buckets:
#   apachespark-sangeet
#   elasticbeanstalk-us-west-2-172658803170
#   kaggle-projects
#   sagemaker-us-west-2-172658803170
#   sangeet-bucket-123
#   sangeet-bucket-321
#   sangeet-lab-instance
# </div>

# %%
import io
import zipfile

s3_resource = session.resource('s3')
zip_obj = s3_resource.Object(bucket_name="kaggle-projects",key='kaggle-roche/kaggle_roche.zip')
buffer = io.BytesIO(zip_obj.get()["Body"].read())

z = zipfile.ZipFile(buffer)
with z as zip_ref:
    zip_ref.extractall("/dbfs/kaggle-roche")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import io
import zipfile

s3_resource = session.resource('s3')
zip_obj = s3_resource.Object(bucket_name="kaggle-projects",key='kaggle-nlp/CORD-19-research-challenge.zip')
buffer = io.BytesIO(zip_obj.get()["Body"].read())

z = zipfile.ZipFile(buffer)
with z as zip_ref:
    zip_ref.extractall("/dbfs/kaggle-nlp")

# %%
import os
list_dirs = os.walk("/dbfs/kaggle-nlp")
for root, dirs, files in list_dirs: 
        for d in dirs: 
            print (os.path.join(root, d))    
        for f in files: 
            print (os.path.join(root, f))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/dbfs/kaggle-nlp/biorxiv_medrxiv
# /dbfs/kaggle-nlp/comm_use_subset
# /dbfs/kaggle-nlp/COVID.DATA.LIC.AGMT.pdf
# /dbfs/kaggle-nlp/biorxiv_medrxiv/biorxiv_medrxiv
# /dbfs/kaggle-nlp/biorxiv_medrxiv/biorxiv_medrxiv/pdf_json
# /dbfs/kaggle-nlp/biorxiv_medrxiv/biorxiv_medrxiv/pdf_json/0015023cc06b5362d332b3baf348d11567ca2fbb.json
# /dbfs/kaggle-nlp/biorxiv_medrxiv/biorxiv_medrxiv/pdf_json/00340eea543336d54adda18236424de6a5e91c9d.json
# /dbfs/kaggle-nlp/biorxiv_medrxiv/biorxiv_medrxiv/pdf_json/004f0f8bb66cf446678dc13cf2701feec4f36d76.json
# ...

# %%
def realname(path, root=None):
    if root is not None:
        path=os.path.join(root, path)
    result=os.path.basename(path)
    if os.path.islink(path):
        realpath=os.readlink(path)
        result= '%s -> %s' % (os.path.basename(path), realpath)
    return result

def ptree(startpath, depth=-1):
    prefix=0
    if startpath != '/':
        if startpath.endswith('/'): startpath=startpath[:-1]
        prefix=len(startpath)
    for root, dirs, files in os.walk(startpath):
        level = root[prefix:].count(os.sep)
        if depth >-1 and level > depth: continue
        indent=subindent =''
        if level > 0:
            indent = '|   ' * (level-1) + '|-- '
        subindent = '|   ' * (level) + '|-- '
        print('{}{}/'.format(indent, realname(root)))
        # print dir only if symbolic link; otherwise, will be printed as root
        for d in dirs:
            if os.path.islink(os.path.join(root, d)):
                print('{}{}'.format(subindent, realname(d, root=root)))
        for f in files:
            print('{}{}'.format(subindent, realname(f, root=root)))

ptree("/dbfs/kaggle-roche")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">kaggle-roche/
# -- UNCOVER/
#    |-- hackathon_file_readme.txt
#    |-- ECDC/
#    |   |-- current-data-on-the-geographic-distribution-of-covid-19-cases-worldwide.csv
#    |-- HDE_update/
#    |   |-- acaps-covid-19-government-measures-dataset.csv
#    |   |-- inform-covid-indicators.csv
#    |   |-- HDE/
#    |   |   |-- global-school-closures-covid-19.csv
#    |   |   |-- italy-high-resolution-population-density-maps-demographic-estimates-elderly-ages-60.csv
#    |   |   |-- total-covid-19-tests-performed-by-country.csv
#    |-- New_York_Times/
#    |   |-- covid-19-county-level-data.csv
#    |   |-- covid-19-state-level-data.csv
# ...
