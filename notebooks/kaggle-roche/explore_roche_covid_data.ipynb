# %%
#### Display tree for Roche Covid file structure
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-659974283303537&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>sdassd
#
# <span class="ansi-red-fg">NameError</span>: name &#39;sdassd&#39; is not defined</div>
